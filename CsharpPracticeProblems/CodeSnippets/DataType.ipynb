// %%
Console.WriteLine("india");
Console.WriteLine("ll");
// Out:
// india
// ll

// %%
// Explicit cast
long longNumber = 509183009109;
int intnumber = (int)longNumber;
Console.WriteLine(intnumber);
// Out:
// -1918099115

// %%
bool ignoreCase = true;
string option = "/help";
// ...
int comparison = string.Compare(option, "/Help", ignoreCase);
Console.WriteLine(comparison);
bool isHelpRequested = (comparison == 0);
// Displays: Help Requested: True
 Console.WriteLine($"Help Requested: {isHelpRequested}");
// Out:
// 0
// Help Requested: True

// %%
int grade = 78;
if(grade >= 60)
{
    Console.WriteLine("passed");
}
// of grade is more that 90 , print A+ 
else if (grade > 90)
{
    Console.WriteLine("A+");
}
else
{
    Console.WriteLine("Failed");
}
// Out:
// passed

// %%
// using conditional operator 
using System.ComponentModel.DataAnnotations;

// if 100 rupees and greater in Account then your account is ValidationAttribute 
// if less that 100 rupeess in account balance is invalid

double account = 1892.89;
if( account >= 100)
    Console.WriteLine("valid");
else 
    Console.WriteLine("invalid");

// Conditional operator 

string result = account >= 100 ? "valid" : "Invalid";
Console.WriteLine(result);
// Out:
// valid
// valid

// %%
string s1 = "Koustav";
string s2 = s1;

if(s1.Equals(s2))
    Console.WriteLine("True");
if(s1 == s2)
    Console.Write("True");
// Out:
// True
// True

// %%
string s1 = "Soumilli";
string s2 = new string("Soumilli");

if(s1.Equals(s2))
    Console.WriteLine("True");

if(s1 == s2)
    Console.Write("True");
// Out:
// True
// True

// %%
String a = "Hello";
String b = new String("Hello");
Console.WriteLine(a == b);
Console.WriteLine(a.Equals(b));// true

Console.WriteLine(Object.ReferenceEquals(a, b)); // false
// Out:
// True
// True
// False
